# %% [markdown]
# ##### W2A1 [Hello World!]
# ##### Hãy viết chương trình in ra dòng chữ "Hello World!" vào ô dưới đây rồi ấn Nộp bài để kiểm tra xem bạn đã biết cách in một thông báo ra màn hình.

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ##### W2A2 [User Input]
# ##### Hàm input() trong Python là một hàm dùng để nhận dữ liệu từ người dùng thông qua bàn phím, hàm này luôn trả về dữ liệu kiểu chuỗi (str). Viết chương trình nhận đầu vào là tên người từ bàn phím và in ra màn hình lời chào tương ứng.

# %%
ten = input("Nhập tên của bạn")
print(f"Xin Chào {ten}")
# Out:
# Xin Chào

# %% [markdown]
# ##### W2A3 [ModAndDiv]
# ##### Viết chương trình nhận vào hai số nguyên a, b từ bàn phím. In ra tổng, hiệu, tích, phần nguyên, phần dư và kết quả chia thực của phép chia a cho b (lấy đến 2 chữ số phần thập phân) theo định dạng đúng của output

# %%
a = int(input("Nhập a: "))
b = int(input("Nhập b: "))

if b != 0:
    print(f"{a} + {b} = {a + b}")
    print(f"{a} - {b} = {a - b}")
    print(f"{a} * {b} = {a * b}")
    print(f"{a} // {b} = {a // b}")
    print(f"{a} % {b} = {a % b}")
    print(f"{a} / {b} = {a / b:.2f}")
else:
    print("Không thể chia cho 0")
# Out:
# 1 + 2 = 3
# 1 - 2 = -1
# 1 * 2 = 2
# 1 // 2 = 0
# 1 % 2 = 1
# 1 / 2 = 0.50

# %% [markdown]
# ##### W2A4
# ##### Viết chương trình python để tính điểm trung bình môn học của một học sinh trong lớp. Có tổng cộng 6 đầu điểm: a1, b1, c1, a2, b2, a3. Trong đó:
# ##### • Các điểm a1, b1, c1 được nhân hệ số 1,
# ##### • Các điểm a2, b2 được nhân hệ số 2,
# ##### • Điểm a3 được nhân hệ số 3.
# ##### ông thức tính điểm trung bình là: TB=((a1+b1+c1)+(a2+b2)×2+a3×3)/10
# ##### Đầu vào: Trong bài tập này, dữ liệu vào chỉ gồm duy nhất một dòng bao gồm 6 số thể hiện cho 6 đầu điểm a1, b1, c1, a2, b2, a3 theo đúng thứ tự đó. Trong đó, hai đầu điểm liên tiếp nhau sẽ được phân tách nhau bởi duy nhất 1 dấu cách. Đầu ra: Đầu ra là giá trị điểm trung bình môn học của 6 môn học, lấy đến 1 chữ số phần thập phân.

# %%
a1 = float(input("Nhập số:   "))
b1 = float(input("Nhập số:   "))
c1 = float(input("Nhập số:   "))
a2 = float(input("Nhập số:   "))
b2 = float(input("Nhập số:   "))
a3 = float(input("Nhập số:   "))

TB = (a1 + b1 + c1 + (a2 + b2) * 2 + a3 * 3) / 10

print(f"{TB:.1f}")

# %% [markdown]
# ##### W2A5 [Exponentiation]
# ##### Trong Python, phép toán mũ (luỹ thừa) được viết bằng **. Ví dụ: để tính 2^3 bạn viết 2**3, và kết quả là 8. Cơ số và số mũ có thể có kiểu float hoặc int. Trong bài này bạn hãy nhập vào hai số a, b (int) cách nhau một dấu cách, tính và in ra kết quả a mũ b.

# %%
a = int(input())
b = int(input())

ket_qua = a ** b

print(ket_qua)

# %% [markdown]
# ##### W2A6 [StringDataType]
# ##### Hãy nhập vào một kí tự chữ cái thường ‘a’…’z’, in ra mã Unicode của nó sau đó chuyển nó thành kí tự hoa tương ứng, in kí tự hoa này ra màn hình.

# %%
char = input()
print(ord(char))
print(char.upper())

# %% [markdown]
# ##### W2A7 [Operations]
# ##### Hãy in ra kết quả của hai biểu thức sau:
# ##### A = ((13 ** 2) * 3) + 5 và B = 13**2*3 + 5
# ##### Chú ý: Hãy để ý phong cách viết mã của A

# %%
A = ((13 ** 2) * 3) + 5
B = 13**2*3 + 5

print(A)
print(B)

# %% [markdown]
# ##### W2A8 [CelsiusTranfer]
# ##### Hãy chuyển sang độ F theo công thức: F = 9/5*C + 32 và in ra màn hình kết quả. Kết quả làm tròn đến hai chữ số thập phân đằng sau dấu phẩy.

# %%
C = float(input("Nhập nhiệt độ C"))

F = (9 / 5) * C + 32

print(round(F, 2))

# %% [markdown]
# ##### W2A9
# ##### Sơn Tùng mua một chiếc đồng hồ Movado trên trang mua sắm trực tuyến Amazon. Chiếc đồng hồ có giá x USD (x nhập từ bàn phím). Bởi Amazon không vận chuyển trực tiếp về Việt Nam, Sơn Tùng phải trả 10 USD cho phí vận chuyển từ một nước trung gian. Khi vận chuyển về Việt Nam, Sơn Tùng được thông báo sẽ phải trả thêm 30% thuế xuất nhập cảnh và 10% thuế VAT cho chiếc đồng hồ nói trên. Viết chương trình tính tổng số tiền mà Sơn Tùng phải trả để mua được chiếc đồng hồ trên (USD). Kết quả làm tròn đến hai chữ số thập phân.

# %%
x = float(input("Hãy nhập số tiền"))
tong_tien = x + 10 + (x * 0.4)
print(round(tong_tien, 2))

# %% [markdown]
# #### W2A10 [Friend Names]: Viết chương trình nhập vào tên 3 người từ bàn phím. In ra màn hình tên theo thứ tự đảo ngược. VD: input ("Bob Alice Helen") thì output: ("Hi Helen, Alice and Bob.")

# %%
name1 = input("Hãy nhập tên")
name2 = input("Hãy nhập tên")
name3 = input("Hãy nhập tên")

print(f"Hi {name3}, {name2} and {name1}.")

# %% [markdown]
# ##### W2A11: Viết chương trình chuyển từ giờ và phút sang giây. Đầu vào gồm hai giá trị chứa số giờ h và số phút m, mỗi giá trị trên một dòng riêng biệt. Đầu ra: In ra màn hình một dòng duy nhất số giờ và phút được chuyển sang đơn vị giây.

# %%
h = int(input("Hãy nhập số giờ"))
m = int(input("Hãy nhập số phút"))

giay = h * 3600 + m * 60

print(giay)

# %% [markdown]
# ##### W2A12: Cho một khối Rubik có độ dài cạnh là n, hãy trả về số lượng miếng dán riêng lẻ cần thiết để bao phủ toàn bộ khối lập phương. Ví dụ, khối rubic có độ dài cạnh là 1 cần 6 miếng dán riêng lẻ. (Lưu ý: một khối rubic có 6 mặt)

# %%
n = int(input("Nhập độ dài cạnh của khối rubik"))
So_mieng_dan = 6 * (n*n)
print(So_mieng_dan)

# %% [markdown]
# ##### W2A13: Nhập vào từ bàn phím hai số nguyên dương a và b, viết chương trình trả về hàng đơn vị của phép tính tích giữa a và b.

# %%
a = int(input("Nhập số"))
b = int(input("Nhập số"))
tich = a * b
hang_don_vi = tich % 10
print(hang_don_vi)

# %% [markdown]
# ##### W2A14: Viết chương trình hoán đổi giá trị giữa hai số a và b mà không cần khai báo thêm một biến/ hàm nào khác.

# %%
a = int(input("Nhập số"))
b = int(input("Nhập số"))
a, b = b, a
print(a)
print(b)

# %% [markdown]
# ##### W2A16 [SeasonsInYear]: Trong bài tập này, bạn sẽ sử dụng hàm print để in nhiều dòng ra màn hình. Có nhiều cách để làm việc này, ví dụ sử dụng nhiều lệnh print hoặc dùng kí tự xuống dòng '\n'. Hãy viết chương trình in ra trên màn hình tên các mùa trong năm bằng tiếng Anh, mỗi mùa trên một dòng, bắt đầu từ "Spring".

# %%
print("Spring\nSummer\nAutumn\nWinter")

# %% [markdown]
# ##### W2A18 [Banner]: Viết chương trình in ra dòng chữ "TDTT" bằng các ký tự # theo mẫu đã cho, đảm bảo khoảng cách giữa các ký tự chính xác để tạo thành hình khối.

# %%
print("###  ####   ###  ###")
print(" #   #   #   #    # ")
print(" #   #   #   #    # ")
print(" #   #   #   #    # ")
print(" #   ####    #    # ")

# %% [markdown]
# ##### W2A19 [Days of the week]: Viết chương trình in ra các ngày trong một tuần bằng tiếng Anh. Mỗi ngày in trên một dòng bắt đầu từ Monday cho đến Sunday.

# %%
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")

# %% [markdown]
# ##### W2A20 [Months of the year]: Viết chương trình in ra các tháng trong một năm bằng tiếng Anh. Mỗi tháng in trên một dòng, bắt đầu từ "January" cho đến "September"

# %%
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")

# %% [markdown]
# ##### W2A21 [Ten Hello World]: Viết chương trình in ra màn hình dòng chữ "Hello, world" 10 lần.

# %%
print(("Hello, world\n") * 10)
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
